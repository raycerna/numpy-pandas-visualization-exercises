# %%
from env import get_db_url
import pandas as pd


url = get_db_url("employees")
sql = """
SELECT * FROM employees LIMIT 20
"""

df = pd.read_sql(sql, url)
df.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
employees=pd.read_sql('''SELECT * FROM titles''',url)

# %%
titles=pd.read_sql('''SELECT * FROM titles''',url)

# %%
employees.shape
# Out:
# (443308, 4)

# %%
titles.shape
# Out:
# (443308, 4)

# %%
employees.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %%
titles.describe(include="all")
# Out:
#                emp_no     title   from_date     to_date
# count   443308.000000    443308      443308      443308
# unique            NaN         7        6393        5888
# top               NaN  Engineer  1998-10-25  9999-01-01
# freq              NaN    115003         132      240124
# mean    253075.034430       NaN         NaN         NaN
# std     161853.292613       NaN         NaN         NaN
# min      10001.000000       NaN         NaN         NaN
# 25%      84855.750000       NaN         NaN         NaN
# 50%     249847.500000       NaN         NaN         NaN
# 75%     424891.250000       NaN         NaN         NaN
# max     499999.000000       NaN         NaN         NaN

# %%
#how many unique title are in the titles dataframe?
pd.read_sql("SELECT COUNT(DISTINCT title) AS unique_title_count from titles", url)
# Out:
#    unique_title_count
# 0                   7

# %%
len(titles.title.unique())
# Out:
# 7

# %%
pd.read_sql("SELECT MIN(to_date) FROM titles", url)
# Out:
#   MIN(to_date)
# 0   1985-03-01

# %%
titles.to_date.min()
# Out:
# datetime.date(1985, 3, 1)

# %%
titles.dtypes
# Out:
# emp_no        int64
# title        object
# from_date    object
# to_date      object
# dtype: object

# %%
##Exercises II
#1 Copy the users and roles DataFrames from the examples above.

#2 What is the result of using a right join on the DataFrames?

#3 What is the result of using an outer join on the DataFrames?

#4 What happens if you drop the foreign keys from the DataFrames and try to merge them?

#5 Load the mpg dataset from PyDataset.

#6 Output and read the documentation for the mpg dataset.

#7 How many rows and columns are in the dataset?

#8 Check out your column names and perform any cleanup you may want on them.

#9 Display the summary statistics for the dataset.

#10 How many different manufacturers are there?

#11 How many different models are there?

#12 Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

#13 Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

#14 Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

#15 Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

#16 Do automatic or manual cars have better miles per gallon?

# %%
import numpy as np

# %%
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
# Perform an outer join specifying the left and right DataFrame keys.

users.merge(roles, left_on='role_id', right_on='id', how='outer', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %%
(users.merge(roles, 
            left_on='role_id', 
            right_on='id', 
            how='outer')
    .drop(columns='role_id')
    .rename(columns={'id_x': 'id', 
                     'name_x': 'employee',
                     'id_y': 'role_id',
                     'name_y': 'role'}
            )
)
# Out:
#     id employee  role_id       role
# 0  1.0      bob      1.0      admin
# 1  2.0      joe      2.0     author
# 2  3.0    sally      3.0   reviewer
# 3  4.0     adam      3.0   reviewer
# 4  5.0     jane      NaN        NaN
# 5  6.0     mike      NaN        NaN
# 6  NaN      NaN      4.0  commenter

# %%
#2.2
users.merge(roles, 
            how="right", 
            left_on="role_id", 
            right_on="id")
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %%
right_join = pd.merge(users,
                     roles,
                     left_on='role_id',
                     right_on='id',
                      how='right',
                     indicator=True)
right_join
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %%
#2.3
users.merge(roles, 
            how="outer", 
            left_on="role_id", 
            right_on="id")
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %%
pd.merge(users,
        roles,
        left_on='role_id',
        right_on='id',
        how='outer',
        indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %%
#2.4
users.drop(columns="role_id").merge(roles, how="outer", on="id")
# Out:
#    id name_x     name_y
# 0   1    bob      admin
# 1   2    joe     author
# 2   3  sally   reviewer
# 3   4   adam  commenter
# 4   5   jane        NaN
# 5   6   mike        NaN

# %%
#bad idea to do this

pd.merge(users,
        roles,
        left_on='id',
        right_on='id',
        how='outer',
        indicator=True)
# Out:
#    id name_x  role_id     name_y     _merge
# 0   1    bob      1.0      admin       both
# 1   2    joe      2.0     author       both
# 2   3  sally      3.0   reviewer       both
# 3   4   adam      3.0  commenter       both
# 4   5   jane      NaN        NaN  left_only
# 5   6   mike      NaN        NaN  left_only

# %%
#2.5
from pydataset import data
df = data("mpg")
df.head(2)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact

# %%
#2.6
data("mpg", show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
#2.7
df.shape
# Out:
# (234, 11)

# %%
#2.8 Check out your column names and perform any cleanup you may want on them.
df.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact

# %%
df = df.rename(columns={
    "cty": "city_mpg",
    "hwy": "hwy_mpg",
    "drv": "drive_sys"
})

df.head(2)
# Out:
#   manufacturer model  displ  year  cyl       trans drive_sys  city_mpg  \
# 1         audi    a4    1.8  1999    4    auto(l5)         f        18
# 2         audi    a4    1.8  1999    4  manual(m5)         f        21
#
#    hwy_mpg fl    class
# 1       29  p  compact
# 2       29  p  compact

# %%
#2.9 Display the summary statistics for the dataset.

df.describe()
# Out:
#             displ         year         cyl    city_mpg     hwy_mpg
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#2.10 How many different manufacturers are there?

df.manufacturer.unique()
# Out:
# array(['audi', 'chevrolet', 'dodge', 'ford', 'honda', 'hyundai', 'jeep',
#        'land rover', 'lincoln', 'mercury', 'nissan', 'pontiac', 'subaru',
#        'toyota', 'volkswagen'], dtype=object)

# %%
df.manufacturer.nunique()
# Out:
# 15

# %%
#2.11 
df.model.unique()
# Out:
# array(['a4', 'a4 quattro', 'a6 quattro', 'c1500 suburban 2wd', 'corvette',
#        'k1500 tahoe 4wd', 'malibu', 'caravan 2wd', 'dakota pickup 4wd',
#        'durango 4wd', 'ram 1500 pickup 4wd', 'expedition 2wd',
#        'explorer 4wd', 'f150 pickup 4wd', 'mustang', 'civic', 'sonata',
#        'tiburon', 'grand cherokee 4wd', 'range rover', 'navigator 2wd',
#        'mountaineer 4wd', 'altima', 'maxima', 'pathfinder 4wd',
#        'grand prix', 'forester awd', 'impreza awd', '4runner 4wd',
#        'camry', 'camry solara', 'corolla', 'land cruiser wagon 4wd',
#        'toyota tacoma 4wd', 'gti', 'jetta', 'new beetle', 'passat'],
#       dtype=object)

# %%
df.model.nunique()
# Out:
# 38

# %%
#2.12 & 13
df['mileage_difference'] = df.hwy_mpg - df.city_mpg

df['average_mileage'] = (df.city_mpg + df.hwy_mpg) / 2

df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drive_sys  city_mpg  \
# 1         audi    a4    1.8  1999    4    auto(l5)         f        18
# 2         audi    a4    1.8  1999    4  manual(m5)         f        21
# 3         audi    a4    2.0  2008    4  manual(m6)         f        20
# 4         audi    a4    2.0  2008    4    auto(av)         f        21
# 5         audi    a4    2.8  1999    6    auto(l5)         f        16
#
#    hwy_mpg fl    class  mileage_difference  average_mileage
# 1       29  p  compact                  11             23.5
# 2       29  p  compact                   8             25.0
# 3       31  p  compact                  11             25.5
# 4       30  p  compact                   9             25.5
# 5       26  p  compact                  10             21.0

# %%
df["average_mileage"] = df[["city_mpg", "hwy_mpg"]].mean(axis=1)
df.head(2)
# Out:
#   manufacturer model  displ  year  cyl       trans drive_sys  city_mpg  \
# 1         audi    a4    1.8  1999    4    auto(l5)         f        18
# 2         audi    a4    1.8  1999    4  manual(m5)         f        21
#
#    hwy_mpg fl    class  mileage_difference  average_mileage
# 1       29  p  compact                  11             23.5
# 2       29  p  compact                   8             25.0

# %%
#2.14

df["is_automatic"] = df.trans.str.contains("auto")
df.head(2)
# Out:
#   manufacturer model  displ  year  cyl       trans drive_sys  city_mpg  \
# 1         audi    a4    1.8  1999    4    auto(l5)         f        18
# 2         audi    a4    1.8  1999    4  manual(m5)         f        21
#
#    hwy_mpg fl    class  mileage_difference  average_mileage  is_automatic
# 1       29  p  compact                  11             23.5          True
# 2       29  p  compact                   8             25.0         False

# %%
df.trans = np.where(df.trans.str.startswith("auto"), "automatic", "manual")
df.head()
# Out:
#   manufacturer model  displ  year  cyl      trans drive_sys  city_mpg  \
# 1         audi    a4    1.8  1999    4  automatic         f        18
# 2         audi    a4    1.8  1999    4     manual         f        21
# 3         audi    a4    2.0  2008    4     manual         f        20
# 4         audi    a4    2.0  2008    4  automatic         f        21
# 5         audi    a4    2.8  1999    6  automatic         f        16
#
#    hwy_mpg fl    class  mileage_difference  average_mileage  is_automatic
# 1       29  p  compact                  11             23.5          True
# 2       29  p  compact                   8             25.0         False
# 3       31  p  compact                  11             25.5         False
# 4       30  p  compact                   9             25.5          True
# 5       26  p  compact                  10             21.0          True

# %%
#2.15

manufacturer_avg_mpg = df.groupby("manufacturer").average_mileage.mean()

manufacturer_avg_mpg.idxmax()
# Out:
# 'honda'

# %%
manufacturer_avg_mpg.sort_values(ascending=False).head(1)
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %%
df.groupby("trans").average_mileage.mean()
# Out:
# trans
# automatic    19.130573
# manual       22.227273
# Name: average_mileage, dtype: float64

# %%
df.groupby('trans')[['average_mileage']].mean().round(1)
# Out:
#            average_mileage
# trans
# automatic             19.1
# manual                22.2

# %%
#Exercises III

#3.1 Use your get_db_url function to help you explore the data from the chipotle database.

#3.2 What is the total price for each order?

#3.3 What are the most popular 3 items?

#3.4 Which item has produced the most revenue?

#3.5 Join the employees and titles DataFrames together.

#3.6 For each title, find the hire date of the employee that was hired most recently with that title.

#3.7 Write the code necessary to create a cross tabulation of the number of titles by department. 
# (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code 
# to perform the manipulations.)

# %%
#3.1 from env import get_db_url


url = get_db_url("chipotle")
sql = """
SELECT * FROM orders 
"""

chipotle = pd.read_sql(sql, url)
chipotle.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %%
#3.2 total price for each order?

chipotle.item_price.sum()
# Out:
# '$2.39 $3.39 $3.39 $2.39 $16.98 $10.98 $1.69 $11.75 $9.25 $9.25 $4.45 $8.75 $8.75 $11.25 $4.45 $2.39 $8.49 $8.49 $2.18 $8.75 $4.45 $8.99 $3.39 $10.98 $3.39 $2.39 $8.49 $8.99 $1.09 $8.49 $2.39 $8.99 $1.69 $8.99 $1.09 $8.75 $8.75 $4.45 $2.95 $11.75 $2.15 $4.45 $11.25 $11.75 $8.75 $10.98 $8.99 $3.39 $8.99 $3.99 $8.99 $2.18 $10.98 $1.09 $8.99 $2.39 $9.25 $11.25 $11.75 $2.15 $4.45 $9.25 $11.25 $8.75 $8.99 $8.99 $3.39 $8.99 $10.98 $8.99 $1.69 $8.99 $3.99 $8.75 $4.45 $8.75 $8.75 $2.15 $8.75 $11.25 $2.15 $9.25 $8.75 $8.75 $9.25 $8.49 $8.99 $1.09 $9.25 $2.95 $11.75 $11.75 $9.25 $11.75 $4.45 $9.25 $4.45 $11.75 $8.75 $8.75 $4.45 $8.99 $8.99 $3.99 $8.49 $3.39 $8.99 $1.09 $9.25 $4.45 $8.75 $2.95 $4.45 $2.39 $8.49 $8.99 $8.49 $1.09 $8.99 $3.99 $8.75 $9.25 $4.45 $11.25 $4.45 $8.99 $1.09 $9.25 $2.95 $4.45 $11.75 $4.45 $8.49 $2.39 $10.98 $22.50 $11.75 $4.45 $11.25 $4.45 $11.25 $4.45 $11.25 $11.25 $11.75 $9.25 $4.45 $11.48 $17.98 $1.69 $17.50 $4.45 $8.49 $2.39 $17.50 $4.45 $4.45 $11.25 $11.75 $10.98 $
# ...

# %%
chipotle.groupby('order_id').item_price.sum()
# Out:
# order_id
# 1       $2.39 $3.39 $3.39 $2.39
# 2                        $16.98
# 3                  $10.98 $1.69
# 4                  $11.75 $9.25
# 5                   $9.25 $4.45
#                   ...
# 1830              $11.75 $11.25
# 1831          $9.25 $2.15 $1.50
# 1832                $8.75 $4.45
# 1833              $11.75 $11.75
# 1834         $11.25 $8.75 $8.75
# Name: item_price, Length: 1834, dtype: object

# %%
chipotle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 216.8+ KB

# %%
chipotle['item_price'] = chipotle.item_price.str.replace('$', '').astype('float')

chipotle.head()
# Out:
# /var/folders/bk/zhdff0zs3yz8v31x8wdnftxm0000gn/T/ipykernel_92896/1851817195.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chipotle['item_price'] = chipotle.item_price.str.replace('$', '').astype('float')
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# ...

# %%
####chipotle['item_price'] = chipotle.item_price.apply(lambda value: float(value[1:].strip()))

# %%
chipotle.groupby('order_id').item_price.agg('sum')

#need to convert object to float panda series exercise
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %%
chipotle.groupby(['item_price']).agg('sum')
# Out:
#                  id  order_id  quantity
# item_price
# 1.09         210934     84666       106
# 1.25         661685    265250       264
# 1.50         326904    130856       117
# 1.69         204277     82040        99
# 1.99           4510      1793         1
# 2.15         470109    188455       192
# 2.18          34837     14049        44
# 2.29           7661      3071         3
# 2.39         204518     82141       100
# 2.50          71312     28573        54
# 2.95         399010    160220       174
# 3.00          23219      9304        19
# 3.27           3643      1459         6
# 3.39          77748     31207        45
# 3.75          14337      5766        21
# 3.89          14896      5993         6
# 3.99         190208     76452        98
# 4.00           2094       854         2
# 4.30          41359     16589        34
# 4.36           2236       901         4
# 4.45         858335    343937       349
# 4.50          14935      5975        12
# ...

# %%
#3.3 most popular items
chipotle.groupby('item_name').quantity.agg('sum').sort_values(ascending=False).head(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %%
#3.4 Which item has produced the most revenue?
chipotle.groupby('item_name').item_price.agg('sum').sort_values(ascending=False).head()
# Out:
# item_name
# Chicken Bowl           7342.73
# Chicken Burrito        5575.82
# Steak Burrito          3851.43
# Steak Bowl             2260.19
# Chips and Guacamole    2201.04
# Name: item_price, dtype: float64

# %%
chipotle.groupby('item_name')[['item_price']].sum().sort_values(by = 'item_price', ascending= False).head()
# Out:
#                      item_price
# item_name
# Chicken Bowl            7342.73
# Chicken Burrito         5575.82
# Steak Burrito           3851.43
# Steak Bowl              2260.19
# Chips and Guacamole     2201.04

# %%
#3.5 join employees and titles df together? ##how='inner'
employee_titles = pd.merge(employees, titles, left_on='emp_no', right_on='emp_no')
employee_titles.head()
# Out:
#    emp_no          title_x from_date_x   to_date_x          title_y  \
# 0   10001  Senior Engineer  1986-06-26  9999-01-01  Senior Engineer
# 1   10002            Staff  1996-08-03  9999-01-01            Staff
# 2   10003  Senior Engineer  1995-12-03  9999-01-01  Senior Engineer
# 3   10004         Engineer  1986-12-01  1995-12-01         Engineer
# 4   10004         Engineer  1986-12-01  1995-12-01  Senior Engineer
#
#   from_date_y   to_date_y
# 0  1986-06-26  9999-01-01
# 1  1996-08-03  9999-01-01
# 2  1995-12-03  9999-01-01
# 3  1986-12-01  1995-12-01
# 4  1995-12-01  9999-01-01

# %%
#3.6
# For each title, find the hire date of the employee that was hired most recently with that title.

url = get_db_url("employees")
sql = """
SELECT * FROM titles 
"""

employees = pd.read_sql(sql, url)
employees.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %%
employee.titles.groupby('title')[['hire_date']].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/bk/zhdff0zs3yz8v31x8wdnftxm0000gn/T/ipykernel_92896/4012340797.py in <module>
# ----> 1 employee.titles.groupby('title')[['hire_date']].max()
#
# NameError: name 'employee' is not defined

# %%
most_recent_hire_date = '''

SELECT title, max(from_date) AS "most_recent_hire_date"

FROM employees
JOIN titles USING(emp_no)

GROUP BY title;

'''
employees.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01
